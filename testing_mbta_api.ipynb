# %%
import requests
import os
import json

API_KEY = "767c9b38180a4f28bec9118a1a5b6753"
stop_id = "place-sstat"
direction = 0

# url = "https://api-v3.mbta.com/lines?sort=color"
url = "https://api-v3.mbta.com/shapes"
params = {
    # "include": "routes"
    # "sort": "short_name"
    "filter[route]": "Red"
}
headers = {
    "x-api-key": API_KEY
}

resp = requests.get(url, params=params, headers=headers)
data = resp.json()

# for pred in data.get("data", []):
#     arrival = pred["attributes"].get("arrival_time")
#     status = pred["attributes"].get("status")
#     print(f"Arrival: {arrival}, Status: {status}")
os.makedirs("data", exist_ok=True)
with open("data/mbta_shapes.json", "w") as f:
    json.dump(data, f, indent=2)
print("done")
# Out:
# done

# %%
with open("data/mbta_routes.json", "r") as f:
        data = json.load(f)
list_of_route_ids = []

for route in data["data"]:
    list_of_route_ids.append(route["id"])
    
# print(list_of_route_ids)
temp_route_ids = list_of_route_ids[0:5]
print(temp_route_ids)
# Out:
# ['Red', 'Mattapan', 'Orange', 'Green-B', 'Green-C']
